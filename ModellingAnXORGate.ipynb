# %% [markdown]
# <a href="https://colab.research.google.com/github/Seneli/ML-Intro-Tutorials/blob/main/ModellingAnXORGate.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Sequential
from tensorflow.keras import layers


xs = np.array([[0,0],[0,1],[1,0],[1,1]],dtype=float)
ys = np.array([0,1,1,0],dtype=float)


## your code goes here
model = Sequential(
    [
        layers.Dense(2, activation="relu", name="layer1"),
        layers.Dense(2, activation="relu", name="layer2"),
        layers.Dense(1, name="layer3"),
    ]
)

model.compile(optimizer="sgd", loss = "mean_squared_error",metrics=['acc'])

history = model.fit(xs, ys, epochs=1000,verbose=2) 

print(model.predict(xs).round())
# Out:
# Epoch 1/1000
# 1/1 - 0s - loss: 0.4777 - acc: 0.5000
# Epoch 2/1000
# 1/1 - 0s - loss: 0.4654 - acc: 0.5000
# Epoch 3/1000
# 1/1 - 0s - loss: 0.4539 - acc: 0.5000
# Epoch 4/1000
# 1/1 - 0s - loss: 0.4430 - acc: 0.5000
# Epoch 5/1000
# 1/1 - 0s - loss: 0.4328 - acc: 0.5000
# Epoch 6/1000
# 1/1 - 0s - loss: 0.4232 - acc: 0.5000
# Epoch 7/1000
# 1/1 - 0s - loss: 0.4142 - acc: 0.5000
# Epoch 8/1000
# 1/1 - 0s - loss: 0.4057 - acc: 0.5000
# Epoch 9/1000
# 1/1 - 0s - loss: 0.3977 - acc: 0.5000
# Epoch 10/1000
# 1/1 - 0s - loss: 0.3901 - acc: 0.5000
# Epoch 11/1000
# 1/1 - 0s - loss: 0.3830 - acc: 0.5000
# Epoch 12/1000
# 1/1 - 0s - loss: 0.3763 - acc: 0.5000
# Epoch 13/1000
# 1/1 - 0s - loss: 0.3700 - acc: 0.5000
# Epoch 14/1000
# 1/1 - 0s - loss: 0.3641 - acc: 0.5000
# Epoch 15/1000
# 1/1 - 0s - loss: 0.3584 - acc: 0.5000
# Epoch 16/1000
# 1/1 - 0s - loss: 0.3531 - acc: 0.5000
# Epoch 17/1000
# 1/1 - 0s - loss: 0.3481 - acc: 0.5000
# Epoch 18/1000
# 1/1 - 0s - loss: 0.3433 - acc: 0.5000
# ...
